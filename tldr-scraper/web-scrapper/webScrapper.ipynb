# %% [markdown]
# # Web Scrapper for **https://tldr.tech/tech/archives**

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %% [markdown]
# ### Getting All TLDR From Archives

# %%
url = "https://tldr.tech/tech/archives"
result = requests.get(url)

soup = bs(result.content)
web_links = soup.select('a') 
actual_web_links = [web_link['href'] for web_link in web_links if not(web_link['href'].find("/tech/")) and len(web_link['href']) == 16]

# %% [markdown]
# ### Getting Content From the First TLDR

# %%
url_individual = f"https://tldr.tech{actual_web_links[0]}"
result_individual = requests.get(url_individual)
individual_TLDR = bs(result_individual.content)

# %%
web_links_individual_TLDR = individual_TLDR.select('a') 
actual_web_links_individual_TLDR = [web_link['href'] for web_link in web_links_individual_TLDR if web_link['href'].find('utm_source=tldrnewsletter') != -1]

# %%
headers_ = individual_TLDR.select('h3')
actual_headers = [str(head)[4:-5] for head in headers_]

# %%
contents_ = individual_TLDR.select('h3')
actual_content = [str(content.parent.parent.select('div')[0])[5:-6] for content in contents_]

# %%
actual_web_links_individual_TLDR
# Out:
# ['https://arstechnica.com/space/2024/03/after-its-third-test-flight-spacexs-starship-could-soon-carry-satellites/?utm_source=tldrnewsletter',
#  'https://www.nbcnews.com/tech/social-media/tiktok-ban-sale-buy-bill-law-download-app-senate-date-rcna143413?utm_source=tldrnewsletter',
#  'https://www.zmescience.com/medicine/cow-human-insulin/?utm_source=tldrnewsletter',
#  'https://arc-website-git-foundation-model-tool-arc-institute.vercel.app/news/blog/evo?utm_source=tldrnewsletter',
#  'https://www.zainrizvi.io/blog/falsehoods-programmers-believe-about-time-zones/?utm_source=tldrnewsletter',
#  'https://alexandrehtrb.github.io/posts/2024/03/http2-and-http3-explained/?utm_source=tldrnewsletter',
#  'https://a16z.com/100-gen-ai-apps/?utm_source=tldrnewsletter',
#  'https://www.yieldcode.blog/post/the-curse-of-the-senior-engineer/?utm_source=tldrnewsletter',
#  'https://danielmangum.com/posts/most-important-skill-startup-engineering-leadership/?utm_source=tldrnewsletter',
# ...

# %%
actual_headers
# Out:
# ['SpaceX celebrates major progress on the third flight of Starship (7 minute read)',
#  'Who could buy TikTok? These are the people who could acquire the app (7 minute read)',
#  'Genetically modified cow makes milk with human insulin (5 minute read)',
#  'Evo: DNA foundation modeling from molecular to genome scale (9 minute read)',
#  'Falsehoods programmers believe about time zones (10 minute read)',
#  'HTTP/2 and HTTP/3 explained (25 minute read)',
#  'The Top 100 Gen AI Consumer Apps (11 minute read)',
#  'The Curse of the Senior Software Engineer (11 minute read)',
#  'The Most Important Skill in Startup Engineering Leadership (4 minute read)',
#  'Snapchat will allow users to save DMs (2 minute read)',
#  'After AWS and Google, Microsoft says it’s removing Azure ‘egress’ data transfer fees — but with caveats (3 minute read)',
#  'Digital forgeries are hard (6 minute read)',
#  'The Future of Farcaster with Dan Romero (22 minute read)',
#  'To The Space Station (Website)']

# %%
actual_content
# Out:
# ["SpaceX's Starship rocket flew halfway around the world yesterday, accomplishing a key demonstration of its ability to carry heavy payloads into low-Earth orbit. The successful launch builds on two previous flights last year. Thursday's flight tested Starship's payload bay door and performed a precursor test of an in-orbit refueling system. Photos from the launch are available in the article.",
#  'ByteDance may have to sell TikTok in the US if a proposed bill passes the Senate. Some high-profile investors, including former Treasury Secretary Steven Mnuchin, online video platform Rumble, and former Activision Blizzard CEO Bobby Kotick, have expressed interest in acquiring the app. This article presents a list of known potential buyers along with a primer on companies that have previously tried to purchase TikTok.',
# ...

# %%
MainDataFrame = pd.DataFrame({
    "Links":actual_web_links_individual_TLDR,
    "Headers":actual_headers,
    "Content":actual_content})

# %%
MainDataFrame
# Out:
#                                                 Links  \
# 0   https://arstechnica.com/space/2024/03/after-it...
# 1   https://www.nbcnews.com/tech/social-media/tikt...
# 2   https://www.zmescience.com/medicine/cow-human-...
# 3   https://arc-website-git-foundation-model-tool-...
# 4   https://www.zainrizvi.io/blog/falsehoods-progr...
# 5   https://alexandrehtrb.github.io/posts/2024/03/...
# 6   https://a16z.com/100-gen-ai-apps/?utm_source=t...
# 7   https://www.yieldcode.blog/post/the-curse-of-t...
# 8   https://danielmangum.com/posts/most-important-...
# 9   https://www.axios.com/2024/03/14/snapchat-mess...
# 10  https://techcrunch.com/2024/03/14/after-aws-an...
# 11  https://mjg59.dreamwidth.org/69507.html?utm_so...
# 12  https://www.generalist.com/briefing/the-future...
# 13  https://www.spacex.com/launches/mission/?missi...
#
#                                               Headers  \
# 0   SpaceX celebrates major progress on the third ...
# ...

# %%
print(individual_TLDR.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link data-precedence="next" href="/_next/static/css/a57e1c55fbc959ac.css" rel="stylesheet"/>
#   <link as="script" fetchpriority="low" href="/_next/static/chunks/webpack-9844d8f1475c24fa.js" rel="preload"/>
#   <script async="" src="/_next/static/chunks/fd9d1056-af3aa282ef378a64.js">
#   </script>
#   <script async="" src="/_next/static/chunks/396464d2-8c61bf22e836a673.js">
#   </script>
#   <script async="" src="/_next/static/chunks/9145-5a9f17db80a1709f.js">
#   </script>
#   <script async="" src="/_next/static/chunks/main-app-0cbeb1bda8826abc.js">
#   </script>
#   <script async="" src="/_next/static/chunks/13b76428-dade03eef2325af2.js">
#   </script>
#   <script async="" src="/_next/static/chunks/6111-c145d6cc364a0ea3.js">
#   </script>
#   <script async="" src="/_next/static/chunks/8009-7e7799a017d713a4.js">
#   </script>
# ...

# %% [markdown]
# ### Getting IMAGES from Link Websites

# %%
dic = {}
for links in actual_web_links_individual_TLDR:
    result = requests.get(links)
    soup = bs(result.content)
    dic[links] = [i["src"] for i in soup.select("img") if i["src"].find("https://") != -1]

# %%
df = pd.DataFrame(dict([(key, pd.Series(value)) for key, value in dic.items()]))

# %% [markdown]
# If df **Length < 6** (MINIMUM Contents) THEN **go to next TLDR**
# - cuz websites doesn't contain correct image format

# %%
new = df.dropna(how='all',axis=1)
len(new.columns)
# Out:
# 7

# %%
MainDataFrame[MainDataFrame["Links"].isin(list(new.columns))]
# Out:
#                                                 Links  \
# 0   https://arstechnica.com/space/2024/03/after-it...
# 1   https://www.nbcnews.com/tech/social-media/tikt...
# 2   https://www.zmescience.com/medicine/cow-human-...
# 4   https://www.zainrizvi.io/blog/falsehoods-progr...
# 10  https://techcrunch.com/2024/03/14/after-aws-an...
# 11  https://mjg59.dreamwidth.org/69507.html?utm_so...
# 12  https://www.generalist.com/briefing/the-future...
#
#                                               Headers  \
# 0   SpaceX celebrates major progress on the third ...
# 1   Who could buy TikTok? These are the people who...
# 2   Genetically modified cow makes milk with human...
# 4   Falsehoods programmers believe about time zone...
# 10  After AWS and Google, Microsoft says it’s remo...
# 11         Digital forgeries are hard (6 minute read)
# 12  The Future of Farcaster with Dan Romero (22 mi...
#
#                                               Content
# ...

# %%
df.dropna(how='all',axis=1)
# Out:
#    https://arstechnica.com/space/2024/03/after-its-third-test-flight-spacexs-starship-could-soon-carry-satellites/?utm_source=tldrnewsletter  \
# 0   https://cdn.arstechnica.net/wp-content/uploads...
# 1   https://cdn.arstechnica.net/wp-content/uploads...
# 2   https://cdn.arstechnica.net/wp-content/themes/...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# ...

# %% [markdown]
# ## Upload Images from Website (Cloudinary)
#
# - Must install dependency **cloudinary**
# - Create .env file
# <br>
# CLOUDINARY_CLOUD_NAME=<br>
# CLOUDINARY_API_KEY=<br>
# CLOUDINARY_API_SECRET=<br>
#
#
# Sources: `https://youtu.be/dDljAsM3T7c?si=0dqP-Se7r2W8WOty`

# %%
# Set your Cloudinary credentials
# ===============================
from dotenv import load_dotenv
load_dotenv()

# Import the Cloudinary libraries
# ===============================
import cloudinary
import cloudinary.uploader


# Import other libraries
import os

# Set your Cloudinary credentials
# ===============================
cloudinary.config(
    cloud_name = os.getenv("CLOUDINARY_CLOUD_NAME"),
    api_key = os.getenv("CLOUDINARY_API_KEY"),
    api_secret = os.getenv("CLOUDINARY_API_SECRET"),
    secure = True
)

# %%
response = cloudinary.uploader.upload("https://cdn.arstechnica.net/wp-content/uploads/2024/03/ift3-entry1.jpg")
print(response["secure_url"])
# Out:
# https://res.cloudinary.com/dkunssecw/image/upload/v1710592036/mxe4v0ljwkjsvfpbpy43.jpg
